# %%
import pandas as pd

# %%
data = pd.read_csv('a-Si.csv')
data.plot('wl', 'n', title='a-Si n')
data.plot('wl', 'k', title='a-Si k')

# %%
data = pd.read_csv('TiO2.csv')
data.plot('wl', 'n', xlim=[0.2, 0.8], title='TiO2, n')
data.plot('wl', 'k', xlim=[0.2, 0.8], title='TiO2, k')
